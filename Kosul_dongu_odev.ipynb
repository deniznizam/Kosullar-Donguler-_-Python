# %% [markdown]
# **Ödev-1:** Kullanıcıdan maaş bilgisini istenir ve bu bilgiye göre maaşından ne kadar vergi kesileceğini hesaplanır. Kullanıcının geliri;
#
# 1. 10000 ve altındaysa maaşından %5 kesinti olur.
# 2. 25000 ve altındaysa maaşından %10 kesinti olur.
# 3. 45000 ve altındaysa maaşından %25 kesinti olur.
# 4. Diğer koşullarda %30 kesinti olur.
#
# Bu durumlara göre kullanıcının yeni maaşı yazdırılır.

# %%
maas = int(input("Lütfen maaşınızı giriniz."))
if maas <= 10000:
    maas = maas - maas*0.05
    print("Maaşınızdan kesilecek vergi ile birlikte gerçek maaşınız ", maas,"TL'dir.") 

elif maas <= 25000:
    maas = maas - maas*0.1
    print("Maaşınızdan kesilecek vergi ile birlikte gerçek maaşınız ", maas,"TL'dir.")

elif maas <= 45000:
    maas = maas - maas*0.25
    print("Maaşınızdan kesilecek vergi ile birlikte gerçek maaşınız ", maas,"TL'dir.")

else :
    maas = maas - maas*0.3
    print("Maaşınızdan kesilecek vergi ile birlikte gerçek maaşınız ", maas,"TL'dir.")
# Out:
# Maaşınızdan kesilecek vergi ile birlikte gerçek maaşınız  9500.0 TL'dir.

# %% [markdown]
# **Ödev-2:** Kullanıcıdan kullanıcı adı ve şifre oluşturmasını istenir. Şifrenin uzunluğu altı haneye ulaşmışsa hesabınız oluşturuldu mesajı alınır, altı haneden azsa altı haneli şifre oluşturması gerektiğinin mesajı alınır. *(Sadece koşul kullanılması yeterli.)*

# %%
isim = str(input("Kullanıcı isminizi giriniz."))
print("Hoşgeldiniz ", isim)

while True:
     sifre = (input("Şifrenizi oluşturunuz."))

     if len(sifre) == 6:
          print("Şifreniz onaylandı")
          break     
     elif len(sifre) < 6:
          print("Şifreniz 6 haneden oluşmalıdır. Daha az değer girdiniz.")
   
     elif len(sifre) > 6:
          print("Şifreniz 6 haneden oluşmalıdır.Çok uzun değer girdiniz.")
# Out:
# Hoşgeldiniz  dwdwadada
# Şifreniz 6 haneden oluşmalıdır.Çok uzun değer girdiniz.
# Şifreniz onaylandı

# %% [markdown]
# **Ödev-3:** Bir önceki örnek geliştirilir.
#
# 1. Kullanıcı girdiği şifre 5 ve 10 hane arasında olmak zorunda.
# 2. Eğer bu koşula uyuyorsa "Hesabınız oluşturuldu." mesajı alır.
# 3. Koşulu sağlamıyorsa "Lütfen girdiniz şifre 5 haneden az 10 haneden fazla olmasın!" uyarısı alır.
# 4. Bunu oluştururken kullanıcı istediğimiz şartlarda şifre oluşturana kadar sormaya devam eder

# %%
isim = str(input("Hoşgeldiniz. Lütfen kullanıcı adınızı belirleyiniz."))
print("Merhaba ", isim)

while True:
    sifre = (input("Şifre oluşturmalısınız. Lütfen en az 5, en çok 10 haneden oluşan şifrenizi giriniz."))
    if  len(sifre) < 5:
        print("Şifreniz lütfen en az 5 haneden oluşsun.")
    elif len(sifre) > 10:
        print("Şifreniz lütfen en çok 10 haneden oluşsun.") 
    else :
        print("Şifreniz başarıyla oluşturuldu.")
        break
# Out:
# Merhaba
# Şifreniz lütfen en az 5 haneden oluşsun.
# Şifreniz lütfen en az 5 haneden oluşsun.
# Şifreniz başarıyla oluşturuldu.

# %% [markdown]
# **Ödev-4:** Kullanıcıdan isim ve şifre isteyeceğiz ve şifre girişi için üç hak verilir.
#
# 1. Eğer önceden tanımlı şifre ile kullanıcıdan gelen şifre aynıysa "Giriş yapıldı." yazar.
# 2. Şifre girişi yanlışsa "Yanlış şifre girildi!" uyarısı verilsin ve üç yanlış denemede program biter.
# 3. Tercihe göre kalan hak bilgisi verilir.

# %%
sifre = "Gelecekhayalim2025"
hak = 3
kalanhak = hak

isim = input("Lütfen kullanıcı adınızı giriniz: ")
print(f"Merhaba {isim}. Giriş yapmak için sadece {hak} hakkınız var.")
while kalanhak > 0 :
    girilen = input(f"Şifrenizi giriniz. {kalanhak} hakkınız var.")
    
    if girilen == sifre:
        print("Şifreniz doğru.Giriş yapılıyor..")
        break
    else :
        kalanhak -= 1 
        if kalanhak > 0:
            print(f"Yanlış şifre girdiniz. {kalanhak} hakkınız kaldı.")
        else :
            print("Giriş haklarınız bitti.Program sonlandırılıyor.")
# Out:
# Merhaba Gelecekhayalim2025. Giriş yapmak için sadece 3 hakkınız var.
# Şifreniz doğru.Giriş yapılıyor..
